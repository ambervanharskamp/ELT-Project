# %%
# %config Completer.use_jedi = False
import yfinance as yf
from config import *
from sqlalchemy import create_engine

# %%
msft = yf.Ticker("MSFT")
aapl = yf.Ticker("AAPL")
goog = yf.Ticker("GOOG")
googl = yf.Ticker("GOOGL")
tsla = yf.Ticker("TSLA")

# %%
msft_stock = yf.download("AAPL", start="2015-01-01", end="2019-12-31")
msft_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-12-31  28.205000  28.282499  27.552500  27.594999  25.057606  165613600
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.819241  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  24.120045  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  24.122320  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.460564  160423600

# %%
msft_stock = msft_stock[["Open","Close"]]
msft_stock.head()
# Out:
#                  Open      Close
# Date
# 2014-12-31  28.205000  27.594999
# 2015-01-02  27.847500  27.332500
# 2015-01-05  27.072500  26.562500
# 2015-01-06  26.635000  26.565001
# 2015-01-07  26.799999  26.937500

# %%
aapl_stock = yf.download("AAPL", start="2015-01-01", end="2019-12-31")
aapl_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-12-31  28.205000  28.282499  27.552500  27.594999  25.057606  165613600
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.819241  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  24.120045  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  24.122320  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.460564  160423600

# %%
aapl_stock = aapl_stock[["Open","Close"]]
aapl_stock.head()
# Out:
#                  Open      Close
# Date
# 2014-12-31  28.205000  27.594999
# 2015-01-02  27.847500  27.332500
# 2015-01-05  27.072500  26.562500
# 2015-01-06  26.635000  26.565001
# 2015-01-07  26.799999  26.937500

# %%
goog_stock = yf.download("GOOG", start="2015-01-01", end="2019-12-31")
goog_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31  529.795471  531.141724  524.360352  524.958740  524.958740
# 2015-01-02  527.561584  529.815369  522.665039  523.373108  523.373108
# 2015-01-05  521.827332  522.894409  511.655243  512.463013  512.463013
# 2015-01-06  513.589966  514.761719  499.678131  500.585632  500.585632
# 2015-01-07  505.611847  505.855164  498.281952  499.727997  499.727997
#
#              Volume
# Date
# 2014-12-31  1368246
# 2015-01-02  1447563
# 2015-01-05  2059840
# 2015-01-06  2899940
# 2015-01-07  2065054

# %%
goog_stock = goog_stock[["Open","Close"]]
goog_stock.head()
# Out:
#                   Open       Close
# Date
# 2014-12-31  529.795471  524.958740
# 2015-01-02  527.561584  523.373108
# 2015-01-05  521.827332  512.463013
# 2015-01-06  513.589966  500.585632
# 2015-01-07  505.611847  499.727997

# %%
googl_stock = yf.download("GOOGL", start="2015-01-01", end="2019-12-31")
msft_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open      Close
# Date
# 2014-12-31  28.205000  27.594999
# 2015-01-02  27.847500  27.332500
# 2015-01-05  27.072500  26.562500
# 2015-01-06  26.635000  26.565001
# 2015-01-07  26.799999  26.937500

# %%
googl_stock = googl_stock[["Open","Close"]]
googl_stock.head()
# Out:
#                   Open       Close
# Date
# 2014-12-31  537.739990  530.659973
# 2015-01-02  532.599976  529.549988
# 2015-01-05  527.150024  519.460022
# 2015-01-06  520.500000  506.640015
# 2015-01-07  510.950012  505.149994

# %%
tsla_stock = yf.download("TSLA", start="2015-01-01", end="2019-12-31")
tsla_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  44.618000  45.136002  44.450001  44.481998  44.481998  11487500
# 2015-01-02  44.574001  44.650002  42.652000  43.862000  43.862000  23822000
# 2015-01-05  42.910000  43.299999  41.431999  42.018002  42.018002  26842500
# 2015-01-06  42.012001  42.840000  40.841999  42.256001  42.256001  31309500
# 2015-01-07  42.669998  42.956001  41.956001  42.189999  42.189999  14842000

# %%
tsla_stock = tsla_stock[["Open","Close"]]
tsla_stock.head()
# Out:
#                  Open      Close
# Date
# 2014-12-31  44.618000  44.481998
# 2015-01-02  44.574001  43.862000
# 2015-01-05  42.910000  42.018002
# 2015-01-06  42.012001  42.256001
# 2015-01-07  42.669998  42.189999

# %%
amzn_stock = yf.download("AMZN", start="2015-01-01", end="2019-12-31")
amzn_stock.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31  311.549988  312.980011  310.010010  310.350006  310.350006
# 2015-01-02  312.579987  314.750000  306.959991  308.519989  308.519989
# 2015-01-05  307.010010  308.380005  300.850006  302.190002  302.190002
# 2015-01-06  302.239990  303.000000  292.380005  295.290009  295.290009
# 2015-01-07  297.500000  301.279999  295.329987  298.420013  298.420013
#
#              Volume
# Date
# 2014-12-31  2048000
# 2015-01-02  2783200
# 2015-01-05  2774200
# 2015-01-06  3519000
# 2015-01-07  2640300

# %%
amzn_stock = amzn_stock[["Open","Close"]]
amzn_stock.head()
# Out:
#                   Open       Close
# Date
# 2014-12-31  311.549988  310.350006
# 2015-01-02  312.579987  308.519989
# 2015-01-05  307.010010  302.190002
# 2015-01-06  302.239990  295.290009
# 2015-01-07  297.500000  298.420013

# %%
# connect to local database
rds_connection_string = "{}:{}@localhost:5432/company_stock_db".format(username,password)

engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# check table names
engine.table_names()
# Out:
# []

# %%
msft_stock.to_sql(name='msft_stock', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\envs\pythondata\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Open" of relation "msft_stock" does not exist
# LINE 1: INSERT INTO msft_stock ("Open", "Close") VALUES (28.20499992...
#                                 ^
#
#
# ...

# %%
aapl_data_new.to_sql(name='company_index', con=engine, if_exists='append', index=False)

# %%
company_index.to_sql(name='company_index', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-fcb662e71b08> in <module>
# ----> 1 company_index.to_sql(name='company_index', con=engine, if_exists='append', index=False)
#
# NameError: name 'company_index' is not defined

# %%
company_index.to_sql(name='company_index', con=engine, if_exists='append', index=False)

# %%
company_index.to_sql(name='company_index', con=engine, if_exists='append', index=False)
